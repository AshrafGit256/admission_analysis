# %% [markdown]
# # 📊 Admission Data Visualization Notebook
# This notebook provides an extensive set of visualizations...

# %%
# %pip install plotly
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.6 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.6 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.6 MB ? eta -:--:--
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_excel('Cleaned_Admission_List.xlsx')
df.columns = df.columns.str.strip().str.lower().str.replace('.', '', regex=False)
urban_districts = ['KAMPALA', 'WAKISO', 'MBARARA', 'JINJA']
df['area_type'] = df['dname'].str.upper().apply(lambda x: 'Urban' if x in urban_districts else 'Rural')

# %%
sns.countplot(data=df, x='ge', palette='Set2')
plt.title('Gender Distribution')
plt.show()

# %%
df['area_type'].value_counts().plot.pie(autopct='%1.1f%%', colors=['lightblue', 'lightgreen'])
plt.title('Urban vs Rural Applicants')
plt.ylabel('')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt

# Create a new encoded column
df['ge_encoded'] = LabelEncoder().fit_transform(df['ge'])

# Compute and plot the heatmap
sns.heatmap(df[['tot_wt', 'ge_encoded']].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
