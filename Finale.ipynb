# %% [markdown]
# # 📘 Admission List Cleaning Notebook
# This notebook walks through the steps used to clean and consolidate the admission list Excel file for analysis.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 📥 Load Excel File

# %%
file_path = 'Admission.xlsx'
df_raw = pd.read_excel(file_path, sheet_name='Table 1', header=None)
df_raw.head(20)
# Out:
#                                              0                      1   \
# 0                           MAKERERE UNIVERSITY                    NaN
# 1               ACADEMIC REGISTRAR'S DEPARTMENT                    NaN
# 2   ADMISSION LISTS FOR 2025/2026 ACADEMIC YEAR                    NaN
# 3      PRIVATE SPONSORSHIP- DIRECT ENTRY SCHEME                    NaN
# 4                         BSC. Accounting (EVE)                    NaN
# 5                                            no                 formid
# 6                                             1   25APF900350094290048
# 7                                             2   25APF561140686250786
# 8                                             3   25APF530278631275455
# 9                                             4  25APF1346250173272930
# 10                                            5  25APF1553620758303031
# 11                                            6  25APF1537469809268568
# 12                                            7    25APF10681047294195
# 13                                            8  25APF1652505897285843
# 14                                            9  25APF1647383334301940
# 15                                           10   25APF984114651285328
# 16                                           11   25APF577994830291646
# 17                                           12   25APF384641141289301
# 18                                           13  25APF1697288461304543
# 19                                           14   25APF201140512278646
#
#            2                        3    4      5      6         7   \
# 0         NaN                      NaN  NaN    NaN    NaN       NaN
# 1         NaN                      NaN  NaN    NaN    NaN       NaN
# 2         NaN                      NaN  NaN    NaN    NaN       NaN
# 3         NaN                      NaN  NaN    NaN    NaN       NaN
# 4         NaN                      NaN  NaN    NaN    NaN       NaN
# 5    index_no                     name   ge  uace_  dcode     dname
# 6   U2789/905        NIMUSIIMA SANDRAH    F   2024     55    WAKISO
# 7   U0025/529  BULUKUKU DANIEL EPHRAIM    M   2014     93    KIBUKU
# 8   U2977/518        MIREMBE ELIZABETH    F   2024     16   KAMPALA
# 9   U1664/712         NAMATA    MARTHA    F   2024     33    MASAKA
# 10  U0004/754           NAKALEMA JOYCE    F   2024     33    MASAKA
# 11  U2000/501             AGABA MARVIN    M   2024     46  NTUNGAMO
# 12  U1664/585          EDENI PRISCILLA    F   2024      3      ARUA
# 13  U0742/607        NAMAGANDA SHITRAH    F   2024     10    IGANGA
# 14  U3216/541           AYEBALE ESTHER    F   2024     32   LUWEERO
# 15  U2732/507         MASEREKA GILBERT    M   2024     21    KASESE
# 16  U3687/528     NABWAMI VENESSA MARY    F   2024    101    LWENGO
# 17  U1716/512     NANKANJA  IMMACULATE    F   2024     16   KAMPALA
# 18  U0036/784             APIO  JULIET    F   2023     67   BUKEDEA
# 19  U0064/631           JULIUS ENGWEDU    M   2024     53    SOROTI
#
#              8                      9       10
# 0           NaN                    NaN     NaN
# 1           NaN                    NaN     NaN
# 2           NaN                    NaN     NaN
# 3           NaN                    NaN     NaN
# 4           NaN                    NaN     NaN
# 5   course_code            course_name  tot_wt
# 6           ACC  BSC. Accounting (EVE)    42.7
# 7           ACC  BSC. Accounting (EVE)    42.3
# 8           ACC  BSC. Accounting (EVE)    41.1
# 9           ACC  BSC. Accounting (EVE)    40.7
# 10          ACC  BSC. Accounting (EVE)    40.3
# 11          ACC  BSC. Accounting (EVE)    39.9
# 12          ACC  BSC. Accounting (EVE)    39.8
# 13          ACC  BSC. Accounting (EVE)    39.6
# 14          ACC  BSC. Accounting (EVE)    39.6
# 15          ACC  BSC. Accounting (EVE)    39.4
# 16          ACC  BSC. Accounting (EVE)    39.4
# 17          ACC  BSC. Accounting (EVE)    38.4
# 18          ACC  BSC. Accounting (EVE)    38.2
# 19          ACC  BSC. Accounting (EVE)    38.2

# %% [markdown]
# ## 🔍 Inspecting Raw Structure

# %% [markdown]
# - The file has introductory rows (unstructured).
# - Each table has a row with headers like `'no', 'formid', ...`.
# - Tables are grouped under program names (e.g. `BSC. Accounting (EVE)`).

# %% [markdown]
# ## 🧹 Extract and Clean Each Table

# %%
tables = []
current_program = None

for i in range(len(df_raw)):
    row = df_raw.iloc[i]
    if str(row[0]).strip().lower() == 'no' and str(row[1]).strip().lower() == 'formid':
        headers = df_raw.iloc[i]
        data_start = i + 1
        data_end = data_start
        while data_end < len(df_raw) and not pd.isna(df_raw.iloc[data_end, 0]):
            data_end += 1

        table = df_raw.iloc[data_start:data_end].copy()
        table.columns = headers
        table = table.dropna(how='all')

        for j in range(i-1, -1, -1):
            candidate = str(df_raw.iloc[j, 0]).strip()
            if candidate and not candidate.lower().startswith('makerere') and 'admission' not in candidate.lower():
                current_program = candidate
                break

        table['program_name'] = current_program
        tables.append(table)

# %%
# Convert 'dcode' to a nullable integer type
df_combined['dcode'] = df_combined['dcode'].astype('Int64')

# Fill missing 'dcode' where 'dname' is 'LUWERO'
df_combined.loc[(df_combined['dname'].str.upper() == 'LUWERO') & (df_combined['dcode'].isna()), 'dcode'] = 32

# Check the rows with 'LUWERO' to confirm
df_combined[df_combined['dname'].str.upper() == 'LUWERO']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Convert 'dcode' to a nullable integer type
# ----> 2 df_combined['dcode'] = df_combined['dcode'].astype('Int64')
#       4 # Fill missing 'dcode' where 'dname' is 'LUWERO'
#       5 df_combined.loc[(df_combined['dname'].str.upper() == 'LUWERO') & (df_combined['dcode'].isna()), 'dcode'] = 32
#
# NameError: name 'df_combined' is not defined

# %% [markdown]
# ## 🔗 Combine All Tables

# %%
df_combined = pd.concat(tables, ignore_index=True)
df_combined.head()
# Out:
#   no                 formid   index_no                     name ge uace_  \
# 0  1   25APF900350094290048  U2789/905        NIMUSIIMA SANDRAH  F  2024
# 1  2   25APF561140686250786  U0025/529  BULUKUKU DANIEL EPHRAIM  M  2014
# 2  3   25APF530278631275455  U2977/518        MIREMBE ELIZABETH  F  2024
# 3  4  25APF1346250173272930  U1664/712         NAMATA    MARTHA  F  2024
# 4  5  25APF1553620758303031  U0004/754           NAKALEMA JOYCE  F  2024
#
#   dcode    dname course_code            course_name tot_wt  \
# 0    55   WAKISO         ACC  BSC. Accounting (EVE)   42.7
# 1    93   KIBUKU         ACC  BSC. Accounting (EVE)   42.3
# 2    16  KAMPALA         ACC  BSC. Accounting (EVE)   41.1
# 3    33   MASAKA         ACC  BSC. Accounting (EVE)   40.7
# 4    33   MASAKA         ACC  BSC. Accounting (EVE)   40.3
#
#             program_name
# 0  BSC. Accounting (EVE)
# 1  BSC. Accounting (EVE)
# 2  BSC. Accounting (EVE)
# 3  BSC. Accounting (EVE)
# 4  BSC. Accounting (EVE)

# %%
# Out:
#        no                 formid  index_no                 name ge uace_  \
# 10379  42  25APF1096305957317713  ZZVX90YU  NAMUYANJA Masituula  F  2024
#
#        dcode   dname course_code      course_name tot_wt          program_name
# 10379     32  LUWERO         BSA  BSC. Accounting   39.2  BSC. Accounting(Day)

# %% [markdown]
# ## Export Cleaned Data

# %%
df_combined.to_excel('Cleaned_Admission_List.xlsx', index=False)
